# %% [markdown]
# **Question 1:**
#
#  Let P(x) be the predicate x≤3. Write a program to compute the truth values
# of P(5) and P(2)?
#
# Sample code
#
# ![Lab 2 Predicate Logic.jpg](data:image/jpeg;base64,...)

# %%
def P(x):
    return x <= 3


print("-----------")
print("P(x)= x <= 3--P(5),P(2)")
print("-----------")
print(P(5))
print(P(2))
# Out:
# -----------
# P(x)= x <= 3--P(5),P(2)
# -----------
# False
# True

# %% [markdown]
# **Question 2:**
#
# Let Q(x,y) be the statement x −y=4. Write a program to find the truth values
# of Q(6,2), Q(1,5), and Q(−2,2).

# %%
def minus(x,y):
  return((x-y)==4)


print("Q(x,y)= x -y = 4 --Q(6,2),Q(1,5),Q(-2,2)")
print(minus(6,2),minus(1,5),minus(-2,2))
# Out:
# Q(x,y)= x -y = 4 --Q(6,2),Q(1,5),Q(-2,2)
# True False False

# %% [markdown]
# **Question 3:**
#
#  The Universal Quantifier , ∀, represents the statement "for all", "for every", "for each".
# When it comes before a statement, it means that statement is true for all values in the
# domain. Let P(x) be the statement x+1>x. Given domain of x as [-3, 3]. Write a program
# to check P(x) is this true for all x in the given domain.
#
# Sample code
#
# ![Lab 2 Predicate Logic.jpg](data:image/jpeg;base64,...)

# %%
def P(x):
    return ((x+1)>x)


all=True
for x in [-3,-2,-1,0,1,2,3]:
  if P(x)== False:
    all=False
    break
print(all)
# Out:
# True

# %% [markdown]
# **Question 4:**
#
#  Let P(x) be the statement x+x>x. Write a program to check P(x) is true for all integers x.

# %%
def P(x):
  return ((x+x)>x)


a=True
num = int(input('How many numbers: '))
for n in range(num):
    x = int(input('Enter integer '))
    if (P(x)==False):
      a=False
      break
if(a==False):
  print("P(x) is not true for all integers x")
else:
  print("P(x) is true for all positive integers x")
# Out:
# How many numbers: 5
# Enter integer 3
# Enter integer 2
# Enter integer 6
# Enter integer 5
# Enter integer 4
# P(x) is true for all positive integers x

# %% [markdown]
# **Question 5:**
#
#  The Existential Quantifier ∃, represents the statement "there exists", "for some", "at least
# one". When it comes before a statement, it means the statement is true for at least one
# value in the domain. Let P(x) be the statement x^2=4. Write a program to check P(x) is
# true for at least one integer x.

# %%
def P(x):
  return ((x*x)==4)


a=False
while (a== False):
    x = int(input('Enter integer '))
    if (P(x)==True):
      a=True
      break
if(a==False):
  print("P(x) is not true for the all value of x")
else:
  print("P(x) is true for some values of x")
# Out:
# Enter integer 5
# Enter integer 3
# Enter integer 2
# P(x) is true for some values of x

# %% [markdown]
# **Question 6:**
#
#  A Boolean formula is called “satisfiable” if you can assign truth values to the
# underlying atoms in such a way that the entire formula comes out true. For example,
# the formula p ^ -q is satisfiable: Write a program to check whether the Boolean
# expression
# ![Lab 2 Predicate Logic.jpg](data:image/jpeg;base64,...)
# is satisfiable of not.

# %%
def expression1(p,q,r):
  return ((p or (not q))and(q or (not r)) and (p or q or r) and ((not p) or (not q) or (not r)))

print("-----------")
d=0
print("p   q    r    (p v -q)^(q v -r)^(r v -p)^(p v q v r)^(-p v -q v -r)")
print("-----------")
for p in [True, False]:
  for q in [True, False]:
    for r in[True, False]:
      a=expression1(p,q,r)
      print(p,q,r,a)
      if(a==True):
        d+=1
if (d>0):
  print("The expression is satisfiable")
else:
  print("The expression is not satisfiable")
# Out:
# -----------
# p   q    r    (p v -q)^(q v -r)^(r v -p)^(p v q v r)^(-p v -q v -r)
# -----------
# True True True False
# True True False True
# True False True False
# True False False True
# False True True False
# False True False False
# False False True False
# False False False False
# The expression is satisfiable
